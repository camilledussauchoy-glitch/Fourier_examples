# %%
import numpy as np
import torch 
import matplotlib.pyplot as plt

# %% [markdown]
# \title{A. Periods and Frequencies}
#
# \item Consider the following signals (assume $t$ is in seconds):
#
#
# \item A single sine wave:
# \[
# $f_1(t) = \sin(2\pi \cdot 3 t)$
# \]
#
# \item The sum of two sine waves with different frequencies:
# \[
# $f_2(t) = \sin(2\pi \cdot 3 t) + \frac{1}{2}\sin(2\pi \cdot 7 t)$
# \]
